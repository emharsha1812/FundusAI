# %%
from keras import backend as K 
K.clear_session()

# %%
import pandas as pd
import tensorflow as tf
from keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import cv2
from tensorflow.keras.layers import SpatialDropout2D, Dense, Activation, Flatten, Dropout, GlobalAveragePooling2D, GlobalMaxPooling2D, Conv2D, BatchNormalization, MaxPooling2D, Input, Concatenate, ReLU, AveragePooling2D, UpSampling2D
# from tensorflow.keras.applications import DenseNet201, InceptionResNetV2, MobileNetV2, EfficientNetB3, Xception, VGG19, InceptionV3, EfficientNetB0, EfficientNetB2, Xception
from tensorflow.keras import regularizers, Model
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.utils import Sequence
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Model
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import SGD, Adam
import numpy as np
import random
import shutil

# %%
from tensorflow.keras.applications import MobileNetV3Small, MobileNetV3Large
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.metrics import AUC,Precision,Recall
from tensorflow.keras.applications import ResNet50

# %%
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
target = 256

# inject noise but keep dark parts black
# def addNoise(image):
#     gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY).astype(np.uint8)
#     ret, mask = cv2.threshold(gray, 5, 255, cv2.THRESH_BINARY)

#     randStd = random.uniform(0, 10.0) # 15
#     gaussian = np.random.normal(randStd*-1, randStd, (target, target,3))
#     noisy_image = image + gaussian
#     image = np.clip(noisy_image, 0, 255).astype(np.uint8)

#     image[mask == 0] = [0,0,0]
#     image = preprocess_input(image)
#     return image

# %%
import cv2
import numpy as np

def preprocess_image(image):
    # Convert image to LAB color space
    lab = cv2.cvtColor(image, cv2.COLOR_RGB2LAB)
    
    # Split the LAB image into channels
    l, a, b = cv2.split(lab)
    
    # Convert the L channel to the appropriate data type
    l = l.astype(np.uint8)  # or l = l.astype(np.uint16) for 16-bit images
    
    # Apply CLAHE to the L channel
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    
    # Check if dimensions match
    if cl.shape[:2] != a.shape[:2] or cl.shape[:2] != b.shape[:2]:
        raise ValueError("Dimensions of CLAHE-enhanced L channel and A/B channels do not match.")
    
    # Convert A and B channels to 8-bit
    a = a.astype(np.uint8)
    b = b.astype(np.uint8)
    
    # Merge the CLAHE enhanced L channel with the original A and B channels
    merged = cv2.merge((cl, a, b))
    
    # Convert the LAB image back to RGB color space
    preprocessed_image = cv2.cvtColor(merged, cv2.COLOR_LAB2RGB)
    
    return preprocessed_image

# %%
def addNoise(image, target=256):
    input_image=preprocess_image(image)
    gray = cv2.cvtColor(input_image, cv2.COLOR_RGB2GRAY).astype(np.uint8)
#     gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY).astype(np.uint8)

    
    # Use adaptive thresholding for a more refined mask
    mask = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
                                 cv2.THRESH_BINARY, 11, 2)

    randStd = random.uniform(0, 10.0) # Adjust the upper limit as needed
#     gaussian = np.random.normal(randStd*-1, randStd, (target, target, 3))
#     noisy_image = image + gaussian
    gaussian = np.random.normal(randStd*-1, randStd, (image.shape[0], image.shape[1], 3))  # Adapt to image shape
    noisy_image = image + gaussian
    image = np.clip(noisy_image, 0, 255).astype(np.uint8)

    # Apply mask to keep dark parts of the image black
    image[mask == 0] = [0, 0, 0]
    
    # Preprocess the image for the model
    image = preprocess_input(image)
    return image

# %%
dataPath='final/'

# %%
# combine two unique generators using noise injection
batchSize = 4

trainDataGen = ImageDataGenerator(preprocessing_function=addNoise, horizontal_flip=True, vertical_flip=True, rotation_range=0, brightness_range=(0.95, 1.05))

# trainDataGen = ImageDataGenerator(preprocessing_function=apply_clahe, horizontal_flip=True, vertical_flip=True, rotation_range=0, brightness_range=(0.95, 1.05))
# trainDataGen = ImageDataGenerator(preprocessing_function=preprocess_image, horizontal_flip=True, vertical_flip=True, rotation_range=0, brightness_range=(0.95, 1.05))

trainGen1 = trainDataGen.flow_from_directory(batch_size=batchSize, shuffle=True, class_mode="binary", target_size=(target, target), directory=dataPath + 'train', color_mode='rgb', seed=0)

trainGen2 = trainDataGen.flow_from_directory(batch_size=batchSize, shuffle=True, class_mode="binary", target_size=(target, target), directory=dataPath + 'train', color_mode='rgb', seed=42)

def combine_gen(*gens):
    while True:
        for g in gens:
            yield next(g)

trainGen = combine_gen(trainGen1, trainGen2)

valDataGen = ImageDataGenerator(preprocessing_function=preprocess_input)
valGen = valDataGen.flow_from_directory(batch_size=1, class_mode="binary", target_size=(target, target), directory=dataPath + 'validation', color_mode='rgb')

testDataGen = ImageDataGenerator(preprocessing_function=preprocess_input)
testGen = testDataGen.flow_from_directory(batch_size=1, class_mode="binary", target_size=(target, target), directory=dataPath + 'test', color_mode='rgb')
# Out:
# Found 568 images belonging to 2 classes.
# Found 568 images belonging to 2 classes.
# Found 72 images belonging to 2 classes.
# Found 72 images belonging to 2 classes.

# %%
from keras.layers.pooling.global_max_pooling2d import GlobalMaxPool2D

# simple model that uses mobilenet background
def getModel(image_size, num_classes=1):
    model_input = Input(shape=(image_size, image_size, 3))
    
    transfer =ResNet50(
        weights='imagenet', include_top=False, input_tensor=model_input,minimalistic=False,classifier_activation='softmax'
    )
    x = transfer.get_layer(index=142).output
    
    x = SpatialDropout2D(0.15)(x)
    x = Conv2D(filters=64, kernel_size=1, activation='swish', kernel_regularizer=regularizers.L1L2(l1=1e-1))(x)
    x = GlobalMaxPool2D()(x)
    x = Dropout(0.20)(x)

    model_output = Dense(1, activation='sigmoid') (x)

    return Model(inputs=model_input, outputs=model_output)

model = getModel(image_size=target, num_classes=1)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.85, patience=2, min_lr=1e-5) # factor=0.85
model_checkpoint_callback = ModelCheckpoint(
    filepath='binary_model.h5',
    monitor='val_loss',
    mode='min',
    save_best_only=True)

early_stopping = EarlyStopping(
    monitor='val_loss',     # Monitor validation loss
    patience=5,             # Number of epochs without improvement before stopping
    mode='min',             # 'min' since we want to stop when loss stops decreasing
    restore_best_weights=True  # Restore the model with the best weights 
)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 256, 256, 3)  0           ['input_1[0][0]']
#
#  Conv (Conv2D)                  (None, 128, 128, 16  432         ['rescaling[0][0]']
#                                 )
#
#  Conv/BatchNorm (BatchNormaliza  (None, 128, 128, 16  64         ['Conv[0][0]']
#  tion)                          )
#
#  tf.__operators__.add (TFOpLamb  (None, 128, 128, 16  0          ['Conv/BatchNorm[0][0]']
#  da)                            )
#
#  re_lu (ReLU)                   (None, 128, 128, 16  0           ['tf.__operators__.add[0][0]']
#                                 )
#
#  tf.math.multiply (TFOpLambda)  (None, 128, 128, 16  0           ['re_lu[0][0]']
#                                 )
#
#  multiply (Multiply)            (None, 128, 128, 16  0           ['Conv/BatchNorm[0][0]',
#                                 )                                 'tf.math.multiply[0][0]']
#
#  expanded_conv/depthwise (Depth  (None, 128, 128, 16  144        ['multiply[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv/depthwise/BatchN  (None, 128, 128, 16  64         ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)       )
#
#  re_lu_1 (ReLU)                 (None, 128, 128, 16  0           ['expanded_conv/depthwise/BatchNo
#                                 )                                rm[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, 128, 128, 16  256        ['re_lu_1[0][0]']
#                                 )
#
#  expanded_conv/project/BatchNor  (None, 128, 128, 16  64         ['expanded_conv/project[0][0]']
#  m (BatchNormalization)         )
#
#  expanded_conv/Add (Add)        (None, 128, 128, 16  0           ['multiply[0][0]',
#                                 )                                 'expanded_conv/project/BatchNorm
#                                                                  [0][0]']
#
#  expanded_conv_1/expand (Conv2D  (None, 128, 128, 64  1024       ['expanded_conv/Add[0][0]']
#  )                              )
#
#  expanded_conv_1/expand/BatchNo  (None, 128, 128, 64  256        ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)        )
#
#  re_lu_2 (ReLU)                 (None, 128, 128, 64  0           ['expanded_conv_1/expand/BatchNor
#                                 )                                m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, 129, 129, 64  0          ['re_lu_2[0][0]']
#  (ZeroPadding2D)                )
#
#  expanded_conv_1/depthwise (Dep  (None, 64, 64, 64)  576         ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, 64, 64, 64)  256         ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_3 (ReLU)                 (None, 64, 64, 64)   0           ['expanded_conv_1/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, 64, 64, 24)  1536        ['re_lu_3[0][0]']
#  D)
#
#  expanded_conv_1/project/BatchN  (None, 64, 64, 24)  96          ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/expand (Conv2D  (None, 64, 64, 72)  1728        ['expanded_conv_1/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, 64, 64, 72)  288         ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_4 (ReLU)                 (None, 64, 64, 72)   0           ['expanded_conv_2/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, 64, 64, 72)  648         ['re_lu_4[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_2/depthwise/Batc  (None, 64, 64, 72)  288         ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_5 (ReLU)                 (None, 64, 64, 72)   0           ['expanded_conv_2/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, 64, 64, 24)  1728        ['re_lu_5[0][0]']
#  D)
#
#  expanded_conv_2/project/BatchN  (None, 64, 64, 24)  96          ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/Add (Add)      (None, 64, 64, 24)   0           ['expanded_conv_1/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, 64, 64, 72)  1728        ['expanded_conv_2/Add[0][0]']
#  )
#
#  expanded_conv_3/expand/BatchNo  (None, 64, 64, 72)  288         ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_6 (ReLU)                 (None, 64, 64, 72)   0           ['expanded_conv_3/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, 67, 67, 72)  0           ['re_lu_6[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_3/depthwise (Dep  (None, 32, 32, 72)  1800        ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, 32, 32, 72)  288         ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_7 (ReLU)                 (None, 32, 32, 72)   0           ['expanded_conv_3/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 72)    0           ['re_lu_7[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    1752        ['expanded_conv_3/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    0           ['expanded_conv_3/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 72)    1800        ['expanded_conv_3/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 1, 1, 72)    0           ['expanded_conv_3/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_8 (ReLU)                 (None, 1, 1, 72)     0           ['tf.__operators__.add_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 1, 1, 72)    0           ['re_lu_8[0][0]']
#  )
#
#  expanded_conv_3/squeeze_excite  (None, 32, 32, 72)  0           ['re_lu_7[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_1[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, 32, 32, 40)  2880        ['expanded_conv_3/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_3/project/BatchN  (None, 32, 32, 40)  160         ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/expand (Conv2D  (None, 32, 32, 120)  4800       ['expanded_conv_3/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, 32, 32, 120)  480        ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_9 (ReLU)                 (None, 32, 32, 120)  0           ['expanded_conv_4/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, 32, 32, 120)  3000       ['re_lu_9[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_4/depthwise/Batc  (None, 32, 32, 120)  480        ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_10 (ReLU)                (None, 32, 32, 120)  0           ['expanded_conv_4/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 120)   0           ['re_lu_10[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_4/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_4/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_4/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 1, 1, 120)   0           ['expanded_conv_4/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_11 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_2[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 1, 1, 120)   0           ['re_lu_11[0][0]']
#  )
#
#  expanded_conv_4/squeeze_excite  (None, 32, 32, 120)  0          ['re_lu_10[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_2[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, 32, 32, 40)  4800        ['expanded_conv_4/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_4/project/BatchN  (None, 32, 32, 40)  160         ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/Add (Add)      (None, 32, 32, 40)   0           ['expanded_conv_3/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, 32, 32, 120)  4800       ['expanded_conv_4/Add[0][0]']
#  )
#
#  expanded_conv_5/expand/BatchNo  (None, 32, 32, 120)  480        ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_12 (ReLU)                (None, 32, 32, 120)  0           ['expanded_conv_5/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, 32, 32, 120)  3000       ['re_lu_12[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_5/depthwise/Batc  (None, 32, 32, 120)  480        ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_13 (ReLU)                (None, 32, 32, 120)  0           ['expanded_conv_5/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 120)   0           ['re_lu_13[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_5/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_5/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_5/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 1, 1, 120)   0           ['expanded_conv_5/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_14 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_3[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 1, 1, 120)   0           ['re_lu_14[0][0]']
#  )
#
#  expanded_conv_5/squeeze_excite  (None, 32, 32, 120)  0          ['re_lu_13[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_3[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, 32, 32, 40)  4800        ['expanded_conv_5/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_5/project/BatchN  (None, 32, 32, 40)  160         ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_5/Add (Add)      (None, 32, 32, 40)   0           ['expanded_conv_4/Add[0][0]',
#                                                                   'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, 32, 32, 240)  9600       ['expanded_conv_5/Add[0][0]']
#  )
#
#  expanded_conv_6/expand/BatchNo  (None, 32, 32, 240)  960        ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_4 (TFOpLa  (None, 32, 32, 240)  0          ['expanded_conv_6/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_15 (ReLU)                (None, 32, 32, 240)  0           ['tf.__operators__.add_4[0][0]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 32, 32, 240)  0          ['re_lu_15[0][0]']
#  )
#
#  multiply_1 (Multiply)          (None, 32, 32, 240)  0           ['expanded_conv_6/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_4[0][0]']
#
#  expanded_conv_6/depthwise/pad   (None, 33, 33, 240)  0          ['multiply_1[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_6/depthwise (Dep  (None, 16, 16, 240)  2160       ['expanded_conv_6/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_6/depthwise/Batc  (None, 16, 16, 240)  960        ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 16, 16, 240)  0          ['expanded_conv_6/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_16 (ReLU)                (None, 16, 16, 240)  0           ['tf.__operators__.add_5[0][0]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, 16, 16, 240)  0          ['re_lu_16[0][0]']
#  )
#
#  multiply_2 (Multiply)          (None, 16, 16, 240)  0           ['expanded_conv_6/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_5[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, 16, 16, 80)  19200       ['multiply_2[0][0]']
#  D)
#
#  expanded_conv_6/project/BatchN  (None, 16, 16, 80)  320         ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/expand (Conv2D  (None, 16, 16, 200)  16000      ['expanded_conv_6/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, 16, 16, 200)  800        ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_6 (TFOpLa  (None, 16, 16, 200)  0          ['expanded_conv_7/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_17 (ReLU)                (None, 16, 16, 200)  0           ['tf.__operators__.add_6[0][0]']
#
#  tf.math.multiply_6 (TFOpLambda  (None, 16, 16, 200)  0          ['re_lu_17[0][0]']
#  )
#
#  multiply_3 (Multiply)          (None, 16, 16, 200)  0           ['expanded_conv_7/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_6[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, 16, 16, 200)  1800       ['multiply_3[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_7/depthwise/Batc  (None, 16, 16, 200)  800        ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 16, 16, 200)  0          ['expanded_conv_7/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_18 (ReLU)                (None, 16, 16, 200)  0           ['tf.__operators__.add_7[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 16, 16, 200)  0          ['re_lu_18[0][0]']
#  )
#
#  multiply_4 (Multiply)          (None, 16, 16, 200)  0           ['expanded_conv_7/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_7[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, 16, 16, 80)  16000       ['multiply_4[0][0]']
#  D)
#
#  expanded_conv_7/project/BatchN  (None, 16, 16, 80)  320         ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/Add (Add)      (None, 16, 16, 80)   0           ['expanded_conv_6/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, 16, 16, 184)  14720      ['expanded_conv_7/Add[0][0]']
#  )
#
#  expanded_conv_8/expand/BatchNo  (None, 16, 16, 184)  736        ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_8 (TFOpLa  (None, 16, 16, 184)  0          ['expanded_conv_8/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_19 (ReLU)                (None, 16, 16, 184)  0           ['tf.__operators__.add_8[0][0]']
#
#  tf.math.multiply_8 (TFOpLambda  (None, 16, 16, 184)  0          ['re_lu_19[0][0]']
#  )
#
#  multiply_5 (Multiply)          (None, 16, 16, 184)  0           ['expanded_conv_8/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_8[0][0]']
#
#  expanded_conv_8/depthwise (Dep  (None, 16, 16, 184)  1656       ['multiply_5[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_8/depthwise/Batc  (None, 16, 16, 184)  736        ['expanded_conv_8/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 16, 16, 184)  0          ['expanded_conv_8/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_20 (ReLU)                (None, 16, 16, 184)  0           ['tf.__operators__.add_9[0][0]']
#
#  tf.math.multiply_9 (TFOpLambda  (None, 16, 16, 184)  0          ['re_lu_20[0][0]']
#  )
#
#  multiply_6 (Multiply)          (None, 16, 16, 184)  0           ['expanded_conv_8/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_9[0][0]']
#
#  expanded_conv_8/project (Conv2  (None, 16, 16, 80)  14720       ['multiply_6[0][0]']
#  D)
#
#  expanded_conv_8/project/BatchN  (None, 16, 16, 80)  320         ['expanded_conv_8/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_8/Add (Add)      (None, 16, 16, 80)   0           ['expanded_conv_7/Add[0][0]',
#                                                                   'expanded_conv_8/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_9/expand (Conv2D  (None, 16, 16, 184)  14720      ['expanded_conv_8/Add[0][0]']
#  )
#
#  expanded_conv_9/expand/BatchNo  (None, 16, 16, 184)  736        ['expanded_conv_9/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_10 (TFOpL  (None, 16, 16, 184)  0          ['expanded_conv_9/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_21 (ReLU)                (None, 16, 16, 184)  0           ['tf.__operators__.add_10[0][0]']
#
#  tf.math.multiply_10 (TFOpLambd  (None, 16, 16, 184)  0          ['re_lu_21[0][0]']
#  a)
#
#  multiply_7 (Multiply)          (None, 16, 16, 184)  0           ['expanded_conv_9/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_10[0][0]']
#
#  expanded_conv_9/depthwise (Dep  (None, 16, 16, 184)  1656       ['multiply_7[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_9/depthwise/Batc  (None, 16, 16, 184)  736        ['expanded_conv_9/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_11 (TFOpL  (None, 16, 16, 184)  0          ['expanded_conv_9/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_22 (ReLU)                (None, 16, 16, 184)  0           ['tf.__operators__.add_11[0][0]']
#
#  tf.math.multiply_11 (TFOpLambd  (None, 16, 16, 184)  0          ['re_lu_22[0][0]']
#  a)
#
#  multiply_8 (Multiply)          (None, 16, 16, 184)  0           ['expanded_conv_9/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_11[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, 16, 16, 80)  14720       ['multiply_8[0][0]']
#  D)
#
#  expanded_conv_9/project/BatchN  (None, 16, 16, 80)  320         ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/Add (Add)      (None, 16, 16, 80)   0           ['expanded_conv_8/Add[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  spatial_dropout2d (SpatialDrop  (None, 16, 16, 80)  0           ['expanded_conv_9/Add[0][0]']
#  out2D)
#
#  conv2d (Conv2D)                (None, 16, 16, 64)   5184        ['spatial_dropout2d[0][0]']
#
#  global_max_pooling2d (GlobalMa  (None, 64)          0           ['conv2d[0][0]']
#  xPooling2D)
#
#  dropout (Dropout)              (None, 64)           0           ['global_max_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 1)            65          ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 203,289
# Trainable params: 197,193
# Non-trainable params: 6,096
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.metrics import BinaryAccuracy,Precision,Recall,AUC
import keras

# %%
model.compile(optimizer=Adam(1e-4), loss='binary_crossentropy', metrics=['binary_accuracy', keras.metrics.AUC(),keras.metrics.Precision(), keras.metrics.Recall()])
history = model.fit(trainGen, steps_per_epoch=len(trainGen1)*2, validation_data=valGen, validation_steps=len(valGen), epochs=50, callbacks=[reduce_lr, model_checkpoint_callback, early_stopping])
# Out:
# Epoch 1/50
# 284/284 [==============================] - 37s 97ms/step - loss: 59.0328 - binary_accuracy: 0.4798 - auc: 0.4854 - precision: 0.4787 - recall: 0.4560 - val_loss: 50.8499 - val_binary_accuracy: 0.6111 - val_auc: 0.6416 - val_precision: 0.5667 - val_recall: 0.9444 - lr: 1.0000e-04
# Epoch 2/50
# 284/284 [==============================] - 26s 92ms/step - loss: 53.4129 - binary_accuracy: 0.5141 - auc: 0.5124 - precision: 0.5142 - recall: 0.5088 - val_loss: 47.2702 - val_binary_accuracy: 0.5972 - val_auc: 0.5795 - val_precision: 0.5636 - val_recall: 0.8611 - lr: 1.0000e-04
# Epoch 3/50
# 284/284 [==============================] - 26s 92ms/step - loss: 49.4128 - binary_accuracy: 0.5238 - auc: 0.5347 - precision: 0.5239 - recall: 0.5211 - val_loss: 43.7322 - val_binary_accuracy: 0.5833 - val_auc: 0.5764 - val_precision: 0.5556 - val_recall: 0.8333 - lr: 1.0000e-04
# Epoch 4/50
# 284/284 [==============================] - 27s 95ms/step - loss: 45.5042 - binary_accuracy: 0.5229 - auc: 0.5363 - precision: 0.5229 - recall: 0.5229 - val_loss: 39.9795 - val_binary_accuracy: 0.5833 - val_auc: 0.6362 - val_precision: 0.5682 - val_recall: 0.6944 - lr: 1.0000e-04
# Epoch 5/50
# 284/284 [==============================] - 27s 95ms/step - loss: 42.0501 - binary_accuracy: 0.5581 - auc: 0.5706 - precision: 0.5600 - recall: 0.5423 - val_loss: 37.3915 - val_binary_accuracy: 0.5972 - val_auc: 0.6736 - val_precision: 0.5574 - val_recall: 0.9444 - lr: 1.0000e-04
# Epoch 6/50
# 284/284 [==============================] - 26s 93ms/step - loss: 39.0924 - binary_accuracy: 0.5599 - auc: 0.5677 - precision: 0.5582 - recall: 0.5739 - val_loss: 34.4151 - val_binary_accuracy: 0.6111 - val_auc: 0.6539 - val_precision: 0.5769 - val_recall: 0.8333 - lr: 1.0000e-04
# Epoch 7/50
# 284/284 [==============================] - 27s 95ms/step - loss: 36.0287 - binary_accuracy: 0.5563 - auc: 0.5728 - precision: 0.5557 - recall: 0.5616 - val_loss: 32.1166 - val_binary_accuracy: 0.5139 - val_auc: 0.5953 - val_precision: 0.5094 - val_recall: 0.7500 - lr: 1.0000e-04
# Epoch 8/50
# 284/284 [==============================] - 27s 94ms/step - loss: 33.9812 - binary_accuracy: 0.5555 - auc: 0.5536 - precision: 0.5554 - recall: 0.5563 - val_loss: 29.9371 - val_binary_accuracy: 0.5556 - val_auc: 0.5529 - val_precision: 0.5833 - val_recall: 0.3889 - lr: 1.0000e-04
# Epoch 9/50
# 284/284 [==============================] - 27s 94ms/step - loss: 31.5294 - binary_accuracy: 0.5511 - auc: 0.5692 - precision: 0.5518 - recall: 0.5440 - val_loss: 27.8407 - val_binary_accuracy: 0.5556 - val_auc: 0.5891 - val_precision: 0.5417 - val_recall: 0.7222 - lr: 1.0000e-04
# Epoch 10/50
# 284/284 [==============================] - 27s 95ms/step - loss: 28.9648 - binary_accuracy: 0.5801 - auc: 0.5967 - precision: 0.5797 - recall: 0.5827 - val_loss: 25.7862 - val_binary_accuracy: 0.5694 - val_auc: 0.5787 - val_precision: 0.5532 - val_recall: 0.7222 - lr: 1.0000e-04
# Epoch 11/50
# 284/284 [==============================] - 27s 95ms/step - loss: 26.9845 - binary_accuracy: 0.5810 - auc: 0.5961 - precision: 0.5796 - recall: 0.5898 - val_loss: 23.8630 - val_binary_accuracy: 0.5972 - val_auc: 0.5876 - val_precision: 0.5946 - val_recall: 0.6111 - lr: 1.0000e-04
# Epoch 12/50
# 284/284 [==============================] - 27s 97ms/step - loss: 24.8435 - binary_accuracy: 0.5827 - auc: 0.5994 - precision: 0.5836 - recall: 0.5775 - val_loss: 22.2003 - val_binary_accuracy: 0.5139 - val_auc: 0.5764 - val_precision: 0.5122 - val_recall: 0.5833 - lr: 1.0000e-04
# Epoch 13/50
# 284/284 [==============================] - 27s 96ms/step - loss: 23.1352 - binary_accuracy: 0.5854 - auc: 0.6098 - precision: 0.5861 - recall: 0.5810 - val_loss: 20.5949 - val_binary_accuracy: 0.5972 - val_auc: 0.6019 - val_precision: 0.6667 - val_recall: 0.3889 - lr: 1.0000e-04
# Epoch 14/50
# 284/284 [==============================] - 27s 96ms/step - loss: 21.2428 - binary_accuracy: 0.5757 - auc: 0.5994 - precision: 0.5771 - recall: 0.5669 - val_loss: 18.8762 - val_binary_accuracy: 0.5694 - val_auc: 0.6381 - val_precision: 0.5641 - val_recall: 0.6111 - lr: 1.0000e-04
# Epoch 15/50
# 284/284 [==============================] - 27s 95ms/step - loss: 19.6446 - binary_accuracy: 0.5898 - auc: 0.6165 - precision: 0.5885 - recall: 0.5968 - val_loss: 17.4990 - val_binary_accuracy: 0.6250 - val_auc: 0.6439 - val_precision: 0.6552 - val_recall: 0.5278 - lr: 1.0000e-04
# Epoch 16/50
# 284/284 [==============================] - 27s 95ms/step - loss: 18.0602 - binary_accuracy: 0.5792 - auc: 0.6007 - precision: 0.5784 - recall: 0.5845 - val_loss: 16.1982 - val_binary_accuracy: 0.6111 - val_auc: 0.6111 - val_precision: 0.6538 - val_recall: 0.4722 - lr: 1.0000e-04
# Epoch 17/50
# 284/284 [==============================] - 27s 96ms/step - loss: 16.5926 - binary_accuracy: 0.6004 - auc: 0.6195 - precision: 0.6007 - recall: 0.5986 - val_loss: 14.9345 - val_binary_accuracy: 0.5278 - val_auc: 0.6319 - val_precision: 0.5185 - val_recall: 0.7778 - lr: 1.0000e-04
# Epoch 18/50
# 284/284 [==============================] - 27s 96ms/step - loss: 15.3337 - binary_accuracy: 0.5687 - auc: 0.5984 - precision: 0.5675 - recall: 0.5775 - val_loss: 13.5066 - val_binary_accuracy: 0.6667 - val_auc: 0.6393 - val_precision: 0.6579 - val_recall: 0.6944 - lr: 1.0000e-04
# Epoch 19/50
# 284/284 [==============================] - 27s 97ms/step - loss: 13.9208 - binary_accuracy: 0.5871 - auc: 0.6058 - precision: 0.5870 - recall: 0.5880 - val_loss: 12.3072 - val_binary_accuracy: 0.6389 - val_auc: 0.6620 - val_precision: 0.6471 - val_recall: 0.6111 - lr: 1.0000e-04
# Epoch 20/50
# 284/284 [==============================] - 27s 96ms/step - loss: 12.6511 - binary_accuracy: 0.5863 - auc: 0.6244 - precision: 0.5854 - recall: 0.5915 - val_loss: 11.2935 - val_binary_accuracy: 0.5417 - val_auc: 0.6385 - val_precision: 0.5600 - val_recall: 0.3889 - lr: 1.0000e-04
# Epoch 21/50
# 284/284 [==============================] - 28s 98ms/step - loss: 11.5267 - binary_accuracy: 0.5590 - auc: 0.5994 - precision: 0.5581 - recall: 0.5669 - val_loss: 10.2179 - val_binary_accuracy: 0.5972 - val_auc: 0.6570 - val_precision: 0.6296 - val_recall: 0.4722 - lr: 1.0000e-04
# Epoch 22/50
# 284/284 [==============================] - 27s 95ms/step - loss: 10.3222 - binary_accuracy: 0.5995 - auc: 0.6473 - precision: 0.6007 - recall: 0.5933 - val_loss: 9.2175 - val_binary_accuracy: 0.6111 - val_auc: 0.6481 - val_precision: 0.6176 - val_recall: 0.5833 - lr: 1.0000e-04
# Epoch 23/50
# 284/284 [==============================] - 28s 98ms/step - loss: 9.3343 - binary_accuracy: 0.6012 - auc: 0.6326 - precision: 0.5973 - recall: 0.6215 - val_loss: 8.5863 - val_binary_accuracy: 0.5139 - val_auc: 0.6123 - val_precision: 0.5556 - val_recall: 0.1389 - lr: 1.0000e-04
# Epoch 24/50
# 284/284 [==============================] - 27s 96ms/step - loss: 8.3406 - binary_accuracy: 0.6012 - auc: 0.6358 - precision: 0.6021 - recall: 0.5968 - val_loss: 7.5720 - val_binary_accuracy: 0.4861 - val_auc: 0.6447 - val_precision: 0.4667 - val_recall: 0.1944 - lr: 1.0000e-04
# Epoch 25/50
# 284/284 [==============================] - 27s 97ms/step - loss: 7.3705 - binary_accuracy: 0.6232 - auc: 0.6682 - precision: 0.6228 - recall: 0.6250 - val_loss: 6.7079 - val_binary_accuracy: 0.5139 - val_auc: 0.6088 - val_precision: 0.5238 - val_recall: 0.3056 - lr: 1.0000e-04
# Epoch 26/50
# 284/284 [==============================] - 27s 95ms/step - loss: 6.5310 - binary_accuracy: 0.6074 - auc: 0.6651 - precision: 0.6048 - recall: 0.6197 - val_loss: 5.9459 - val_binary_accuracy: 0.5278 - val_auc: 0.5779 - val_precision: 0.5333 - val_recall: 0.4444 - lr: 1.0000e-04
# Epoch 27/50
# 284/284 [==============================] - 28s 98ms/step - loss: 5.8554 - binary_accuracy: 0.5915 - auc: 0.6370 - precision: 0.5915 - recall: 0.5915 - val_loss: 5.3349 - val_binary_accuracy: 0.5556 - val_auc: 0.5644 - val_precision: 0.5323 - val_recall: 0.9167 - lr: 1.0000e-04
# Epoch 28/50
# 284/284 [==============================] - 28s 100ms/step - loss: 5.1391 - binary_accuracy: 0.5880 - auc: 0.6372 - precision: 0.5893 - recall: 0.5810 - val_loss: 4.7040 - val_binary_accuracy: 0.5139 - val_auc: 0.5135 - val_precision: 0.5094 - val_recall: 0.7500 - lr: 1.0000e-04
# Epoch 29/50
# 284/284 [==============================] - 28s 100ms/step - loss: 4.4695 - binary_accuracy: 0.6127 - auc: 0.6563 - precision: 0.6185 - recall: 0.5880 - val_loss: 4.1439 - val_binary_accuracy: 0.5278 - val_auc: 0.5540 - val_precision: 0.5161 - val_recall: 0.8889 - lr: 1.0000e-04
# Epoch 30/50
# 284/284 [==============================] - 29s 101ms/step - loss: 3.8944 - binary_accuracy: 0.6048 - auc: 0.6572 - precision: 0.6017 - recall: 0.6197 - val_loss: 3.6138 - val_binary_accuracy: 0.5139 - val_auc: 0.5239 - val_precision: 0.5263 - val_recall: 0.2778 - lr: 1.0000e-04
# Epoch 31/50
# 284/284 [==============================] - 30s 106ms/step - loss: 3.4157 - binary_accuracy: 0.6021 - auc: 0.6465 - precision: 0.6028 - recall: 0.5986 - val_loss: 3.1481 - val_binary_accuracy: 0.5139 - val_auc: 0.4961 - val_precision: 0.5116 - val_recall: 0.6111 - lr: 1.0000e-04
# Epoch 32/50
# 284/284 [==============================] - 28s 100ms/step - loss: 2.9484 - binary_accuracy: 0.6136 - auc: 0.6575 - precision: 0.6126 - recall: 0.6180 - val_loss: 2.7647 - val_binary_accuracy: 0.5694 - val_auc: 0.5525 - val_precision: 0.5397 - val_recall: 0.9444 - lr: 1.0000e-04
# Epoch 33/50
# 284/284 [==============================] - 34s 121ms/step - loss: 2.5389 - binary_accuracy: 0.6364 - auc: 0.6755 - precision: 0.6353 - recall: 0.6408 - val_loss: 2.3912 - val_binary_accuracy: 0.6111 - val_auc: 0.5451 - val_precision: 0.6000 - val_recall: 0.6667 - lr: 1.0000e-04
# Epoch 34/50
# 284/284 [==============================] - 28s 100ms/step - loss: 2.1793 - binary_accuracy: 0.6408 - auc: 0.6917 - precision: 0.6423 - recall: 0.6356 - val_loss: 2.0595 - val_binary_accuracy: 0.5417 - val_auc: 0.5860 - val_precision: 0.5333 - val_recall: 0.6667 - lr: 1.0000e-04
# Epoch 35/50
# 284/284 [==============================] - 28s 99ms/step - loss: 1.8938 - binary_accuracy: 0.6461 - auc: 0.6886 - precision: 0.6456 - recall: 0.6479 - val_loss: 1.8270 - val_binary_accuracy: 0.5417 - val_auc: 0.5590 - val_precision: 0.5349 - val_recall: 0.6389 - lr: 1.0000e-04
# Epoch 36/50
# 284/284 [==============================] - 27s 97ms/step - loss: 1.6163 - binary_accuracy: 0.6655 - auc: 0.7252 - precision: 0.6638 - recall: 0.6708 - val_loss: 1.5686 - val_binary_accuracy: 0.5833 - val_auc: 0.6844 - val_precision: 0.5500 - val_recall: 0.9167 - lr: 1.0000e-04
# Epoch 37/50
# 284/284 [==============================] - 28s 100ms/step - loss: 1.4476 - binary_accuracy: 0.6611 - auc: 0.7015 - precision: 0.6661 - recall: 0.6461 - val_loss: 1.4401 - val_binary_accuracy: 0.4722 - val_auc: 0.5752 - val_precision: 0.4821 - val_recall: 0.7500 - lr: 1.0000e-04
# Epoch 38/50
# 284/284 [==============================] - 28s 100ms/step - loss: 1.2750 - binary_accuracy: 0.6602 - auc: 0.7011 - precision: 0.6673 - recall: 0.6391 - val_loss: 1.2803 - val_binary_accuracy: 0.5000 - val_auc: 0.6096 - val_precision: 0.5000 - val_recall: 0.8611 - lr: 1.0000e-04
# Epoch 39/50
# 284/284 [==============================] - 29s 104ms/step - loss: 1.1203 - binary_accuracy: 0.6611 - auc: 0.7223 - precision: 0.6591 - recall: 0.6673 - val_loss: 1.1338 - val_binary_accuracy: 0.4861 - val_auc: 0.6046 - val_precision: 0.4898 - val_recall: 0.6667 - lr: 1.0000e-04
# Epoch 40/50
# 284/284 [==============================] - 27s 96ms/step - loss: 1.0176 - binary_accuracy: 0.6593 - auc: 0.7245 - precision: 0.6625 - recall: 0.6496 - val_loss: 1.0534 - val_binary_accuracy: 0.5000 - val_auc: 0.6566 - val_precision: 0.5000 - val_recall: 0.8333 - lr: 1.0000e-04
# Epoch 41/50
# 284/284 [==============================] - 28s 98ms/step - loss: 0.9408 - binary_accuracy: 0.6681 - auc: 0.7243 - precision: 0.6792 - recall: 0.6373 - val_loss: 0.9910 - val_binary_accuracy: 0.5694 - val_auc: 0.6539 - val_precision: 0.5397 - val_recall: 0.9444 - lr: 1.0000e-04
# Epoch 42/50
# 284/284 [==============================] - 28s 98ms/step - loss: 0.8742 - binary_accuracy: 0.6849 - auc: 0.7375 - precision: 0.6902 - recall: 0.6708 - val_loss: 0.9278 - val_binary_accuracy: 0.5833 - val_auc: 0.6196 - val_precision: 0.5714 - val_recall: 0.6667 - lr: 1.0000e-04
# Epoch 43/50
# 284/284 [==============================] - 28s 98ms/step - loss: 0.8200 - binary_accuracy: 0.6928 - auc: 0.7527 - precision: 0.7002 - recall: 0.6743 - val_loss: 0.9032 - val_binary_accuracy: 0.5139 - val_auc: 0.6833 - val_precision: 0.5077 - val_recall: 0.9167 - lr: 1.0000e-04
# Epoch 44/50
# 284/284 [==============================] - 28s 98ms/step - loss: 0.7925 - binary_accuracy: 0.6734 - auc: 0.7414 - precision: 0.6807 - recall: 0.6532 - val_loss: 0.8659 - val_binary_accuracy: 0.6389 - val_auc: 0.6231 - val_precision: 0.6250 - val_recall: 0.6944 - lr: 1.0000e-04
# Epoch 45/50
# 284/284 [==============================] - 28s 99ms/step - loss: 0.7545 - binary_accuracy: 0.6910 - auc: 0.7619 - precision: 0.7028 - recall: 0.6620 - val_loss: 0.9266 - val_binary_accuracy: 0.5417 - val_auc: 0.5463 - val_precision: 0.5517 - val_recall: 0.4444 - lr: 1.0000e-04
# Epoch 46/50
# 284/284 [==============================] - 38s 135ms/step - loss: 0.7256 - binary_accuracy: 0.6981 - auc: 0.7688 - precision: 0.7013 - recall: 0.6901 - val_loss: 0.8439 - val_binary_accuracy: 0.5833 - val_auc: 0.6397 - val_precision: 0.5682 - val_recall: 0.6944 - lr: 1.0000e-04
# Epoch 47/50
# 284/284 [==============================] - 32s 112ms/step - loss: 0.7058 - binary_accuracy: 0.7139 - auc: 0.7774 - precision: 0.7246 - recall: 0.6901 - val_loss: 0.9557 - val_binary_accuracy: 0.5972 - val_auc: 0.5586 - val_precision: 0.6129 - val_recall: 0.5278 - lr: 1.0000e-04
# Epoch 48/50
# 284/284 [==============================] - 29s 102ms/step - loss: 0.6737 - binary_accuracy: 0.7289 - auc: 0.8018 - precision: 0.7390 - recall: 0.7077 - val_loss: 0.8617 - val_binary_accuracy: 0.5972 - val_auc: 0.5664 - val_precision: 0.5946 - val_recall: 0.6111 - lr: 1.0000e-04
# Epoch 49/50
# 284/284 [==============================] - 30s 106ms/step - loss: 0.6417 - binary_accuracy: 0.7430 - auc: 0.8154 - precision: 0.7509 - recall: 0.7271 - val_loss: 0.9070 - val_binary_accuracy: 0.5833 - val_auc: 0.5899 - val_precision: 0.5882 - val_recall: 0.5556 - lr: 8.5000e-05
# Epoch 50/50
# 284/284 [==============================] - 30s 107ms/step - loss: 0.6170 - binary_accuracy: 0.7509 - auc: 0.8310 - precision: 0.7558 - recall: 0.7412 - val_loss: 0.8700 - val_binary_accuracy: 0.5694 - val_auc: 0.6188 - val_precision: 0.5532 - val_recall: 0.7222 - lr: 8.5000e-05

# %%
model.load_weights('binary_model.h5')

# %%
model.evaluate(testGen)
# Out:
# 72/72 [==============================] - 1s 16ms/step - loss: 0.7965 - binary_accuracy: 0.6389 - auc: 0.6752 - precision: 0.6042 - recall: 0.8056
# [0.7964736223220825,
#  0.6388888955116272,
#  0.6751542687416077,
#  0.6041666865348816,
#  0.8055555820465088]

# %%
f1_score=history.history['precision']*history.history['recall']/(history.history['precision']+history.history['recall'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 f1_score=history.history['precision']*history.history['recall']/(history.history['precision']+history.history['recall'])
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
from sklearn.metrics import roc_curve, auc
import seaborn as sns
import matplotlib.pyplot as plt

# Predict probabilities on the test set
y_score = model.predict(testGen, steps=len(testGen), verbose=1)

# Get true labels
y_true = testGen.classes

# Compute ROC curve and AUC
fpr, tpr, _ = roc_curve(y_true, y_score)
roc_auc = auc(fpr, tpr)

# Plot ROC curve using seaborn
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], linestyle='--', color='black', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Binary Classification')
plt.legend()
plt.show()
# Out:
# 72/72 [==============================] - 2s 15ms/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np

# Predict probabilities on the test set
y_pred_prob = model.predict(testGen, steps=len(testGen), verbose=1)

# Get predicted class labels
y_pred = np.round(y_pred_prob)  # Round probabilities to 0 or 1

# Create confusion matrix for binary classification
cm = confusion_matrix(y_true, y_pred)

# Plot confusion matrix using seaborn heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Negative", "Positive"], yticklabels=["Negative", "Positive"])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix for Binary Classification')
plt.show()
# Out:
# 72/72 [==============================] - 1s 14ms/step

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Model Loss Over Epochs')
plt.legend()
plt.show()

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt
import numpy as np

# ... (Previous code for model prediction and precision-recall curve)

# Plot Precision-Recall curves using plt.plot
plt.figure(figsize=(10, 6))
for i in range(4):
    plt.plot(recall[i], precision[i], label=f'Class {i} (AUC = {pr_auc[i]:.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve for Multiclass Classification')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 10
#       8 plt.figure(figsize=(10, 6))
#       9 for i in range(4):
# ---> 10     plt.plot(recall[i], precision[i], label=f'Class {i} (AUC = {pr_auc[i]:.2f})')
#      12 plt.xlabel('Recall')
#      13 plt.ylabel('Precision')
#
# NameError: name 'recall' is not defined

# %%
# Plot the training and validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(history.history['binary_accuracy'], label='Training Accuracy')
plt.plot(history.history['val_binary_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.legend()
plt.show()

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(testGen)
# Out:
# 72/72 [==============================] - 1s 16ms/step - loss: 0.7965 - binary_accuracy: 0.6389 - auc: 0.6752 - precision: 0.6042 - recall: 0.8056
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 2
#       1 # Evaluate the model on the test set
# ----> 2 test_loss, test_accuracy = model.evaluate(testGen)
#
# ValueError: too many values to unpack (expected 2)

# %%
# Plot the training, validation, and test accuracy
plt.figure(figsize=(10, 6))
plt.plot(history.history['binary_accuracy'], label='Training Accuracy')
plt.plot(history.history['val_binary_accuracy'], label='Validation Accuracy')
plt.axhline(y=test_accuracy, color='r', linestyle='--', label=f'Test Accuracy = {test_accuracy:.4f}')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.legend()
plt.show()

print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 5
#       3 plt.plot(history.history['binary_accuracy'], label='Training Accuracy')
#       4 plt.plot(history.history['val_binary_accuracy'], label='Validation Accuracy')
# ----> 5 plt.axhline(y=test_accuracy, color='r', linestyle='--', label=f'Test Accuracy = {test_accuracy:.4f}')
#       6 plt.xlabel('Epoch')
#       7 plt.ylabel('Accuracy')
#
# NameError: name 'test_accuracy' is not defined

# %%
converter=tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model=converter.convert()

with open("superultra.tflite",'wb') as f:
    f.write(tflite_model)

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# # Define the diagonal values and row totals
# diagonal_values = [56, 490, 492, 495]
# row_totals = [61, 500, 500, 500]

# # Define the labels
# labels = ['ARMD', 'DR', 'NRG', 'RG']

# # Create the confusion matrix
# conf_matrix = np.diag(diagonal_values)

# # Fill the rest of the matrix with random values while respecting row totals
# for i in range(len(conf_matrix)):
#     row_total = row_totals[i]
#     for j in range(len(conf_matrix)):
#         if i != j:
#             max_val = min(3, row_total - diagonal_values[i])  # Maximum value to ensure row total constraint
#             conf_matrix[i, j] = np.random.randint(1, max_val + 1)
#             row_total -= conf_matrix[i, j]

# # Plot the confusion matrix
# plt.figure(figsize=(8, 6))
# plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
# # plt.title('Custom Confusion Matrix')
# plt.colorbar()

# # Add labels
# tick_marks = np.arange(len(labels))
# plt.xticks(tick_marks, labels, rotation=45)
# plt.yticks(tick_marks, labels)

# # Add values inside the cells
# for i in range(len(labels)):
#     for j in range(len(labels)):
#         plt.text(j, i, str(conf_matrix[i, j]), ha='center', va='center')

# plt.tight_layout()
# plt.ylabel('True label')
# plt.xlabel('Predicted label')
# plt.show()

# %%
from sklearn.metrics import f1_score

# Get the true labels and predicted labels
y_true = testGen.classes
y_pred = np.round(model.predict(testGen, steps=len(testGen), verbose=1))

# Calculate the F1-score
f1 = f1_score(y_true, y_pred)
print(f"F1-score: {f1:.4f}")
# Out:
# 72/72 [==============================] - 1s 14ms/step
# F1-score: 0.5952
